# %% [markdown]
# Q1
# 홍길동 씨의 과목별 점수는 다음과 같다. 홍길동 씨의 평균 점수를 구해 보자.
#
# 과목	점수
# 국어	80
# 영어	75
# 수학	55

# %%
name = "Mr.Hong"
ko = 80
en = 75
ma = 55
avgPoint = (ko + en + ma)/3
print(name,"의 평균 점수는",avgPoint)
# Out:
# Mr.Hong 의 평균 점수는 70.0

# %% [markdown]
# Q2
# 자연수 13이 홀수인지 짝수인지 판별할 수 있는 방법에 대해 말해 보자.

# %%
num = 12
if(num%2 ==0):
  print("num은 짝수입니다.")

else:
  print("num은 홀수입니다.")
# Out:
# num은 짝수입니다.

# %% [markdown]
# Q3
# 홍길동 씨의 주민등록번호는 881120-1068234이다. 홍길동 씨의 주민등록번호를 연월일(YYYYMMDD) 부분과 그 뒤의 숫자 부분으로 나누어 출력해 보자.
#
# ※ 문자열 슬라이싱 기법을 사용해 보자.

# %%
citizenNum = "8811201068234"
print("19"+citizenNum[:6],citizenNum[6:])
print("19"+citizenNum[:6],citizenNum[-7:])
# Out:
# 19881120 1068234
# 19881120 1068234

# %% [markdown]
# Q4
# 주민등록번호 뒷자리의 맨 첫 번째 숫자는 성별을 나타낸다. 주민등록번호에서 성별을 나타내는 숫자를 출력해 보자.
#
# >>> pin = "881120-1068234"
# ※ 문자열 인덱싱을 사용해 보자.

# %%
pin = "881120-1068234"
if (pin[7] == "1"):
  print("남성입니다")
else :
  print("여성입니다")
# Out:
# 남성입니다

# %% [markdown]
# Q5
# 다음과 같은 문자열 a:b:c:d가 있다. 문자열의 replace 함수를 사용하여 a#b#c#d로 바꿔서 출력해 보자.
#
# >>> a = "a:b:c:d"

# %%
a = "a:b:c:d"
print(a.replace(":","#"))
# Out:
# a#b#c#d

# %% [markdown]
# Q6
# [1, 3, 5, 4, 2] 리스트를 [5, 4, 3, 2, 1]로 만들어 보자.
#
# ※ 리스트의 내장 함수를 사용해 보자.

# %%
list1=[1,3,5,4,2]
list1.sort()
list1.reverse()
print(list1)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# Q7
# ['Life', 'is', 'too', 'short'] 리스트를 Life is too short 문자열로 만들어 출력해 보자.
#
# ※ 문자열의 join 함수를 사용하면 리스트를 문자열로 쉽게 만들 수 있다.

# %%
a=['Life','is','too','short']
" ".join(a)
print(" ".join(a))
# Out:
# Life is too short

# %% [markdown]
# Q8
# (1,2,3) 튜플에 값 4를 추가하여 (1,2,3,4)를 만들어 출력해 보자.
#
# ※ 더하기(+)를 사용해 보자.

# %%
t1=(1,2,3)
t2=(4,)
print(t1+t2)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# Q9
# 다음과 같은 딕셔너리 a가 있다.
#
# >>> a = dict()
# >>> a
# {}
# 다음 중 오류가 발생하는 경우를 고르고, 그 이유를 설명해 보자.
#
# a['name'] = 'python'
# a[('a',)] = 'python'
# a[[1]] = 'python'
# a[250] = 'python'
