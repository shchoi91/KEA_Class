# %%
import matplotlib.pyplot as plt
import numpy as np

xs = np.array([10,9,3,2,11], dtype=np.float64)
ys = np.array([90,80,50,60,40], dtype=np.float64)
plt.scatter(xs,ys)

a = 3
b = 43
ys2 = xs*a + b
plt.plot(xs, ys2, color = "yellow")
answer = 5 * a + b
print("answer is %d"%answer)
# Out:
# answer is 58

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

xs= np.array([10,9,3,2,11], dtype=np.float64).reshape(5,1)
ys= np.array([90,80,50,60,40], 
dtype=np.float64).reshape(5,1)
xpredict= np.array([5,6]).reshape(2,1)

regr = linear_model.LinearRegression()
regr.fit(xs, ys)
ypredict= regr.predict(xpredict)

plt.scatter(xs, ys)
plt.scatter(xpredict, ypredict)
